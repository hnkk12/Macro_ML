# %% [markdown]
# # 01. FRED & Yahoo Finance Data Downloader
#
# This notebook loads the raw macroeconomic indicators from FRED (including NBER recession indicators, yield curves, labor market indicators) and daily S&P 500 data from Yahoo Finance. If the local cache is missing, it automatically downloads the latest series.

# %%
import sys
import os

CWD = r"D:\NCKH ML Macro\Recession-Predictor-master"
if CWD not in sys.path:
    sys.path.append(CWD)

from src.data_processing import load_raw_data

raw_data = load_raw_data()
print("Raw data shape:", raw_data.shape)
print(raw_data.tail())
