# %% [markdown]
# # 04. Model Evaluation, Calibration, and SHAP Explainability
#
# This notebook evaluates all models using ROC-AUC, PR-AUC, F1-Score, Brier Score, and calibration curves. It also performs warning lead-time analysis and generates SHAP explainability plots.

# %%
import sys
import os

CWD = r"D:\NCKH ML Macro\Recession-Predictor-master"
if CWD not in sys.path:
    sys.path.append(CWD)

from src.evaluation import run_evaluation_pipeline
from src.explain import generate_shap_plots

run_evaluation_pipeline()
generate_shap_plots()
