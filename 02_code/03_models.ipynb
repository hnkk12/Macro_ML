# %% [markdown]
# # 03. Machine Learning Models and Time-Series Backtesting
#
# This notebook implements walk-forward expanding-window cross-validation. It trains traditional econometric baselines and machine learning models (including hyperparameter tuning and a Stacked Ensemble classifier).

# %%
import sys
import os

CWD = r"D:\NCKH ML Macro\Recession-Predictor-master"
if CWD not in sys.path:
    sys.path.append(CWD)

from src.models import run_walk_forward_backtest

run_walk_forward_backtest()
