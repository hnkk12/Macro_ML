# %% [markdown]
# # 02. Feature Engineering & Multi-Horizon Target Construction
#
# This notebook constructs the recession targets for 3, 6, and 12-month horizons. It also engineers a high-dimensional feature panel containing spreads, lags, differences, rolling volatilities, and growth rates.

# %%
import sys
import os

CWD = r"D:\NCKH ML Macro\Recession-Predictor-master"
if CWD not in sys.path:
    sys.path.append(CWD)

from src.features import run_feature_pipeline

run_feature_pipeline()
